# %% [markdown]
# # The Paleobiology Database Tutorial
# This tutorial will teach you how to access data from the [Paleobiology Database (PBDB)](https://paleobiodb.org/navigator/).
#
# ## What is the Paleobiology Database?
# PBDB is a public database of paleontological data that anyone can use, maintained by an international non-governmental group of paleontologists. One of its main features is its navigator, which allows a user to sort data by geological time, taxa, authorizer, stratigraphy, and more. PBDB is run by the Department of Geoscience at the University of Wisconsin-Madison. The project team consists of Shanan Peters, Michael McClennan, and John Czaplewski.
#
# ## How do you access the data?
# PBDB is free to use and has no requirements for access. After sorting through the PBDB navigator and finding the dataset you want to download, click on the button to the left called "save map data". A window will appear, giving you two choices. You can either download the data as a CSV, JSON, TSV, or RIS file, or you can obtain a URL that can be used for external scripts such as R or Python. If you choose to download the data as a file, it can be used automatically for analysis. However, accessing the data by making HTTP requests is a little more intensive. This tutorial will teach you how to obtain the data desired by using the URL, and will require installation of Python. Instructions for download can be found [at this link](https://realpython.com/installing-python/).

# %% [markdown]
# ## Obtaining data through HTTP requests
#
# 1) Obtain your URL by clicking on the "Get URL" tab in the window discussed above. <br>
# 2) Click "Get URL" for the label "Data URL". Copy this url for later use. <br>
# 3) Open the command prompt by typing "cmd" into your search bar, usually found at the top or bottom of you screen. A black box should appear. <br>
# 4) Open up a Python interpreter by typing "python". <br>
# 5) Enter this next block of code line by line:

# %% [markdown]
# >>> import requests
# >>> URL = "your URL here"
# >>> r = requests.get(url=URL)
# >>> data = r.json()

# %% [markdown]
# Try printing data by calling print(data) and you should see your data outputted into the command line! <br>
# As an example, I will use the URL "https://paleobiodb.org/data1.2/occs/list.json?lngmin=-143.2617&lngmax=-75.7617&latmin=31.3536&latmax=48.5748&interval_id=15&base_id=10707,52775&show=coords,attr,loc,prot,time,strat,stratext,lith,lithext,geo,rem,ent,entname,crmod&datainfo", which is a datset on Jurassic Dinosaurs in the Western US.

# %%
import requests
URL = "https://paleobiodb.org/data1.2/occs/list.json?lngmin=-143.2617&lngmax=-75.7617&latmin=31.3536&latmax=48.5748&interval_id=15&base_id=10707,52775&show=coords,attr,loc,prot,time,strat,stratext,lith,lithext,geo,rem,ent,entname,crmod&datainfo"
r = requests.get(url=URL) 
dino_data = r.json() #converts to a json file
dino_data
# Out:
# {'access_time': 'Fri 2018-10-05 21:20:41 GMT',
#  'data_license': 'Creative Commons CC-BY',
#  'data_provider': 'The Paleobiology Database',
#  'data_source': 'The Paleobiology Database',
#  'data_url': 'http://paleobiodb.org/data1.2/occs/list.json?lngmin=-143.2617&lngmax=-75.7617&latmin=31.3536&latmax=48.5748&interval_id=15&base_id=10707,52775&show=coords,attr,loc,prot,time,strat,stratext,lith,lithext,geo,rem,ent,entname,crmod&datainfo',
#  'documentation_url': 'http://paleobiodb.org/data1.2/occs/list_doc.html',
#  'elapsed_time': 0.482,
#  'license_url': 'http://creativecommons.org/licenses/by/4.0/',
#  'parameters': {'base_id': '10707,52775',
#   'interval_id': '15',
#   'latmax': '48.5748',
#   'latmin': '31.3536',
#   'lngmax': '-75.7617',
#   'lngmin': '-143.2617',
#   'show': 'coords,attr,loc,prot,time,strat,stratext,lith,lithext,geo,rem,ent,entname,crmod',
#   'taxon_status': 'all',
#   'timerule': 'major'},
#  'records': [{'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:11924',
#    'cny': 'Mesa',
#    'cxi': 41,
#    'dcr': '2017-11-02 14:56:21',
#    'dmd': '2017-11-02 14:56:21',
#    'eag': 157.3,
#    'eid': 'rei:34164',
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'fluvial-lacustrine indet.',
#    'ff1': 'Y',
#    'ggc': "In Redlands SW of Fruita, CO; near base of Serpent's Trail, near E entrance to Colorado NM. Now on private land, S side of No Thoroughfare Canyon, sec 29, T11S, R101W.",
#    'gsc': 'small collection',
#    'la1': 'green',
#    'lag': 145,
#    'lat': 39.068802,
#    'ldc': '"variegated clays...alternation between green and purplish bands does not mark andy variation in the nature of hardness of these massive joint clays. There are frequent layers of clay nodules, sometimes calcareous, and a few ledges of nodular gray sandstone which are confined to limited areas. Occasional thick ledges of cross-bedded sandstone and lenticular masses of greenish sand occur at almost all levels, but these are likewise of limited extent. Near the top...the clays take on a more sandy nature." (Riggs 1901)',
#    'lng': -108.699989,
#    'lt1': 'claystone',
#    'lt2': 'sandstone',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:139307',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'NPS',
#    'rid': 'ref:63746',
#    'rnk': 3,
#    'scm': 'described as "lower Como Beds"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Colorado',
#    'tid': 'txn:52961',
#    'tna': 'Camarasaurus grandis'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:11925',
#    'cny': 'Mesa',
#    'cxi': 125,
#    'dcr': '2001-09-19 09:11:44',
#    'dmd': '2005-11-22 09:28:42',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'fluvial-lacustrine indet.',
#    'ff2': 'Y',
#    'ggc': '2 mi S of Fruita, CO; 100 feet above Riggs Quarry 12; N of mouth of Wedding Canyon',
#    'gsc': 'small collection',
#    'la1': 'green,red,blue',
#    'la2': 'green',
#    'lag': 152.1,
#    'lat': 39.111668,
#    'ldc': '"variegated clays...alternation between green and purplish bands does not mark andy variation in the nature of hardness of these massive joint clays. There are frequent layers of clay nodules, sometimes calcareous, and a few ledges of nodular gray sandstone which are confined to limited areas. Occasional thick ledges of cross-bedded sandstone and lenticular masses of greenish sand occur at almost all levels, but these are likewise of limited extent. Near the top...the clays take on a more sandy nature." (Riggs 1901)',
#    'lng': -108.717499,
#    'lt1': 'claystone',
#    'lt2': '"shale"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'FMNH P-6641',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:139308',
#    'prc': '__',
#    'ptd': 'NPS',
#    'rid': 'ref:4209',
#    'rnk': 3,
#    'scm': 'described as "upper Como Beds"',
#    'sfm': 'Morrison',
#    'smb': 'Salt Wash',
#    'ssc': 'bed',
#    'stp': 'Colorado',
#    'tid': 'txn:54168',
#    'tna': 'Camarasaurus supremus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13212',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2002-01-29 12:56:29',
#    'dmd': '2014-07-25 16:16:45',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'wet floodplain',
#    'ff1': 'Y',
#    'gcm': 'poorly drained floodplain',
#    'ggc': 'SW 1/4 of SW 1/4 of sec. 10, T22N, R77W, Como Bluff, Albany Co., WY',
#    'gsc': 'small collection',
#    'idn': 'n. gen. Creosaurus n. sp. atrox',
#    'iid': 'txn:52970',
#    'lag': 145,
#    'lat': 41.893101,
#    'lng': -106.041,
#    'lt1': 'claystone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'YPM 1890',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:149592',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:7813',
#    'rnk': 3,
#    'scm': 'referred to in paper as "Atlantosaurus Beds" and "Como Beds"; upper middle part of formation',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tdf': 'subjective synonym of',
#    'tid': 'txn:52962',
#    'tna': 'Allosaurus fragilis'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13214',
#    'cny': 'Converse',
#    'cxi': 41,
#    'dcr': '2002-01-29 13:00:06',
#    'dmd': '2014-08-04 09:06:19',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'unspecified locality in the Freeze Out Mountains, Converse Co.',
#    'gsc': 'outcrop',
#    'idn': 'Creosaurus atrox',
#    'iid': 'txn:52970',
#    'lag': 145,
#    'lat': 42.035831,
#    'lng': -106.389999,
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:149596',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:4387',
#    'rnk': 3,
#    'scm': 'referred to in text as "Atlantosaurus Beds" and "Como Beds", and as Lower Cretaceous',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tdf': 'subjective synonym of',
#    'tid': 'txn:52962',
#    'tna': 'Allosaurus fragilis'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13214',
#    'cny': 'Converse',
#    'cxi': 41,
#    'dcr': '2002-01-29 13:00:06',
#    'dmd': '2014-08-04 09:06:19',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'unspecified locality in the Freeze Out Mountains, Converse Co.',
#    'gsc': 'outcrop',
#    'lag': 145,
#    'lat': 42.035831,
#    'lng': -106.389999,
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:149597',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:4387',
#    'rnk': 3,
#    'scm': 'referred to in text as "Atlantosaurus Beds" and "Como Beds", and as Lower Cretaceous',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:52962',
#    'tna': 'Allosaurus fragilis'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13214',
#    'cny': 'Converse',
#    'cxi': 41,
#    'dcr': '2002-01-29 13:00:06',
#    'dmd': '2014-08-04 09:06:19',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'unspecified locality in the Freeze Out Mountains, Converse Co.',
#    'gsc': 'outcrop',
#    'idn': 'Diplodocus sp.',
#    'lag': 145,
#    'lat': 42.035831,
#    'lng': -106.389999,
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:149598',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:4387',
#    'rnk': 5,
#    'scm': 'referred to in text as "Atlantosaurus Beds" and "Como Beds", and as Lower Cretaceous',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:38669',
#    'tna': 'Diplodocus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13214',
#    'cny': 'Converse',
#    'cxi': 41,
#    'dcr': '2002-01-29 13:00:06',
#    'dmd': '2014-08-04 09:06:19',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'unspecified locality in the Freeze Out Mountains, Converse Co.',
#    'gsc': 'outcrop',
#    'idn': 'Stegosaurus sp.',
#    'lag': 145,
#    'lat': 42.035831,
#    'lng': -106.389999,
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:149599',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:4387',
#    'rnk': 5,
#    'scm': 'referred to in text as "Atlantosaurus Beds" and "Como Beds", and as Lower Cretaceous',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:38814',
#    'tna': 'Stegosaurus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13214',
#    'cny': 'Converse',
#    'cxi': 41,
#    'dcr': '2002-01-29 13:00:06',
#    'dmd': '2014-09-03 15:05:07',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'unspecified locality in the Freeze Out Mountains, Converse Co.',
#    'gsc': 'outcrop',
#    'idn': 'Morosaurus grandis',
#    'iid': 'var:64505',
#    'lag': 145,
#    'lat': 42.035831,
#    'lng': -106.389999,
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'KUVP 1354',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:149600',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:52556',
#    'rnk': 3,
#    'scm': 'referred to in text as "Atlantosaurus Beds" and "Como Beds", and as Lower Cretaceous',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tdf': 'recombined as',
#    'tid': 'txn:52961',
#    'tna': 'Camarasaurus grandis'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13214',
#    'cny': 'Converse',
#    'cxi': 41,
#    'dcr': '2002-01-29 13:00:06',
#    'dmd': '2014-08-04 09:06:19',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'unspecified locality in the Freeze Out Mountains, Converse Co.',
#    'gsc': 'outcrop',
#    'idn': 'Antrodemus valens',
#    'iid': 'var:64031',
#    'lag': 145,
#    'lat': 42.035831,
#    'lng': -106.389999,
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:149601',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:4387',
#    'rnk': 3,
#    'scm': 'referred to in text as "Atlantosaurus Beds" and "Como Beds", and as Lower Cretaceous',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tdf': 'subjective synonym of',
#    'tid': 'txn:52962',
#    'tna': 'Allosaurus fragilis'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13279',
#    'cny': 'Coconino',
#    'cxi': 43,
#    'dcr': '2002-02-13 13:12:47',
#    'dmd': '2012-12-13 01:43:45',
#    'eag': 199.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'wet floodplain',
#    'ff1': 'Y',
#    'gcm': 'paleoenvironment described as including "southwestardly flowing rivers, rising from highlands...and meandering across a broad alluvial plain into low-lying marshes."',
#    'ggc': '80 km NE of Flagstaff, AZ, at West Moenkopi Plateau on the Ward Terrace. Within the Navajo Indian Reservation, about 10 km SW of Sand Springs, AZ. Locality is about 0.5 km SE of Rock Head (topographic feature).',
#    'gsc': 'outcrop',
#    'idn': 'n. gen. Scutellosaurus n. sp. lawleri',
#    'la2': 'red',
#    'lag': 182.7,
#    'lat': 35.679169,
#    'ldc': 'Fluvial sandstones, silts and claystones, predominately red in color. There are also local deposits of silicified limestones, and clay pellet conglomerates. These sediments are characteristically flat-bedded and in places they show cross-laminations. Moreover it is obvious that sand dunes occurred in the western and northwestern extend of the exposures...Two facies are recognized...at its type locality, a sandstone facies...to the southwest [it] increases rapidly in thickness and silt content. About 75 miles southwest of Kayenta...the formation is represented by a silty facies which is markedly different in outcrop character from the sandstone facies.',
#    'lf2': 'lithified',
#    'lm2': 'silty',
#    'lng': -111.027779,
#    'lt1': 'siltstone',
#    'lt2': 'sandstone',
#    'mdf': 'R. Butler',
#    'mdi': 'prs:327',
#    'ocm': 'MNA P1.175, almost complete skeleton (holotype)',
#    'oei': 'Sinemurian',
#    'oid': 'occ:149981',
#    'oli': 'Pliensbachian',
#    'prc': '__',
#    'rid': 'ref:4405',
#    'rnk': 3,
#    'scm': 'middle part of formation',
#    'sfm': 'Kayenta',
#    'sgr': 'Glen Canyon',
#    'smb': 'Silty Facies',
#    'ssc': 'bed',
#    'stp': 'Arizona',
#    'tid': 'txn:67088',
#    'tna': 'Scutellosaurus lawleri'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13280',
#    'cxi': 43,
#    'dcr': '2002-02-13 13:19:49',
#    'dmd': '2012-12-13 01:44:55',
#    'eag': 199.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'wet floodplain',
#    'ff1': 'Y',
#    'ff2': 'Y',
#    'gcm': 'paleoenvironment described as including "southwestardly flowing rivers, rising from highlands...and meandering across a broad alluvial plain into low-lying marshes."',
#    'ggc': 'along Gold Spring Wash, about 16 km NW of MNA 219; on Ward Terrace along the Adeii Eechii Cliffs.',
#    'la1': 'red',
#    'lag': 182.7,
#    'lat': 35.736668,
#    'ldc': 'Fluvial sandstones, silts and claystones, predominately red in color. There are also local deposits of silicified limestones, and clay pellet conglomerates. These sediments are characteristically flat-bedded and in places they show cross-laminations. Moreover it is obvious that sand dunes occurred in the western and northwestern extend of the exposures...Two facies are recognized...at its type locality, a sandstone facies...to the southwest [it] increases rapidly in thickness and silt content. About 75 miles southwest of Kayenta...the formation is represented by a silty facies which is markedly different in outcrop character from the sandstone facies.',
#    'lf1': 'lithified',
#    'lf2': 'lithified',
#    'lm2': 'silty',
#    'lng': -111.073608,
#    'lt1': 'sandstone',
#    'lt2': 'sandstone',
#    'mdf': 'R. Butler',
#    'mdi': 'prs:327',
#    'ocm': 'MNA P1.1752, partial skeleton (paratype)',
#    'oei': 'Sinemurian',
#    'oid': 'occ:149982',
#    'oli': 'Pliensbachian',
#    'prc': '__',
#    'rid': 'ref:4405',
#    'rnk': 3,
#    'sfm': 'Kayenta',
#    'sgr': 'Glen Canyon',
#    'smb': 'Silty Facies',
#    'ssc': 'bed',
#    'stp': 'Arizona',
#    'tid': 'txn:67088',
#    'tna': 'Scutellosaurus lawleri'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13341',
#    'cny': 'Jefferson',
#    'cxi': 41,
#    'dcr': '2002-02-28 11:59:43',
#    'dmd': '2015-08-27 10:15:03',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': '"channel"',
#    'ff1': 'Y',
#    'ff2': 'Y',
#    'gcm': 'channel deposit in a poorly drained floodplain environment; fossils from both layers',
#    'ggc': 'sec. 35, T4S, R70W, Morrison, Colorado; along Dinosaur Ridge',
#    'gsc': 'small collection',
#    'idn': 'Apatosaurus n. sp. laticollis',
#    'iid': 'txn:52974',
#    'la1': 'black',
#    'la2': 'yellow',
#    'lag': 145,
#    'lat': 39.653423,
#    'ldc': 'black mudstone and buff sandstone beds',
#    'lng': -105.187332,
#    'lt1': 'mudstone',
#    'lt2': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'YPM 1861',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:150311',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:5981',
#    'rnk': 3,
#    'scm': 'two layers; upper middle part of formation',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'group of beds',
#    'stp': 'Colorado',
#    'tdf': 'subjective synonym of',
#    'tid': 'txn:57752',
#    'tna': 'Apatosaurus louisae'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13352',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2002-03-01 16:16:35',
#    'dmd': '2013-04-08 15:41:23',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'pond',
#    'ff1': 'Y',
#    'gcm': 'ponds and swamps in deltas or floodplains',
#    'ggc': 'Sheep Creek, 25 miles NE of Medicine Bow, WY; orig. in Carbon Co.',
#    'gsc': 'outcrop',
#    'la1': 'gray',
#    'lag': 145,
#    'lat': 42.152302,
#    'ldc': 'limestone-marl with silt and clay, gray',
#    'lm1': 'argillaceous',
#    'lng': -105.916199,
#    'lt1': 'marl',
#    'lt2': '"limestone"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'CM 94',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:150350',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:1808',
#    'rnk': 3,
#    'scm': '30-40 ft above Quarry E',
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:65917',
#    'tna': 'Diplodocus carnegii'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13352',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2013-04-09 08:40:04',
#    'dmd': '2013-04-08 17:40:04',
#    'eag': 157.3,
#    'eid': 'rei:28458',
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'pond',
#    'ff1': 'Y',
#    'gcm': 'ponds and swamps in deltas or floodplains',
#    'ggc': 'Sheep Creek, 25 miles NE of Medicine Bow, WY; orig. in Carbon Co.',
#    'gsc': 'outcrop',
#    'idn': 'Apatosaurus excelsus',
#    'iid': 'var:56547',
#    'la1': 'gray',
#    'lag': 145,
#    'lat': 42.152302,
#    'ldc': 'limestone-marl with silt and clay, gray',
#    'lm1': 'argillaceous',
#    'lng': -105.916199,
#    'lt1': 'marl',
#    'lt2': '"limestone"',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:150351',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:46207',
#    'rnk': 3,
#    'scm': '30-40 ft above Quarry E',
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tdf': 'recombined as',
#    'tid': 'txn:52982',
#    'tna': 'Brontosaurus excelsus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13352',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2002-03-01 16:16:35',
#    'dmd': '2013-04-11 15:46:19',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'pond',
#    'ff1': 'Y',
#    'gcm': 'ponds and swamps in deltas or floodplains',
#    'ggc': 'Sheep Creek, 25 miles NE of Medicine Bow, WY; orig. in Carbon Co.',
#    'gsc': 'outcrop',
#    'idn': 'Stegosaurus sp.',
#    'la1': 'gray',
#    'lag': 145,
#    'lat': 42.152302,
#    'ldc': 'limestone-marl with silt and clay, gray',
#    'lm1': 'argillaceous',
#    'lng': -105.916199,
#    'lt1': 'marl',
#    'lt2': '"limestone"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'CM 106, 579–80, 598–600, 88 (now UMMP V 16779)',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:150352',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:1808',
#    'rnk': 5,
#    'scm': '30-40 ft above Quarry E',
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:38814',
#    'tna': 'Stegosaurus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13352',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2002-03-01 16:16:35',
#    'dmd': '2013-04-08 15:41:23',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'pond',
#    'ff1': 'Y',
#    'gcm': 'ponds and swamps in deltas or floodplains',
#    'ggc': 'Sheep Creek, 25 miles NE of Medicine Bow, WY; orig. in Carbon Co.',
#    'gsc': 'outcrop',
#    'idn': 'Dinosauria indet.',
#    'la1': 'gray',
#    'lag': 145,
#    'lat': 42.152302,
#    'ldc': 'limestone-marl with silt and clay, gray',
#    'lm1': 'argillaceous',
#    'lng': -105.916199,
#    'lt1': 'marl',
#    'lt2': '"limestone"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:150353',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:1808',
#    'rnk': 25,
#    'scm': '30-40 ft above Quarry E',
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:52775',
#    'tna': 'Dinosauria'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13352',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2002-03-01 16:16:35',
#    'dmd': '2013-04-08 15:41:23',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'pond',
#    'ff1': 'Y',
#    'gcm': 'ponds and swamps in deltas or floodplains',
#    'ggc': 'Sheep Creek, 25 miles NE of Medicine Bow, WY; orig. in Carbon Co.',
#    'gsc': 'outcrop',
#    'idn': 'Morosaurus sp.',
#    'iid': 'txn:52968',
#    'la1': 'gray',
#    'lag': 145,
#    'lat': 42.152302,
#    'ldc': 'limestone-marl with silt and clay, gray',
#    'lm1': 'argillaceous',
#    'lng': -105.916199,
#    'lt1': 'marl',
#    'lt2': '"limestone"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'CM 584',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:150354',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:1808',
#    'rnk': 5,
#    'scm': '30-40 ft above Quarry E',
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tdf': 'subjective synonym of',
#    'tid': 'txn:38697',
#    'tna': 'Camarasaurus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13409',
#    'cny': 'Coconino',
#    'cxi': 43,
#    'dcr': '2002-03-19 13:11:37',
#    'dmd': '2017-08-02 10:59:02',
#    'eag': 199.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ff1': 'Y',
#    'ggc': 'center of flat below Tuba City, 200 yards NE of road fence at dinosaur track locality, which is on the road to Moenave 0.13 miles N of Navajo 1 hwy to Tuba City. 20 miles N of Cameron, AZ in the Navajo Indian Reservation. SW 1/4, sec 34, T32N, R10E.',
#    'gsc': 'small collection',
#    'idn': 'Megalosaurus n. sp. wetherilli',
#    'iid': 'var:55479',
#    'la1': 'blue',
#    'la2': 'brown,gray',
#    'lag': 182.7,
#    'lat': 36.145279,
#    'ldc': '"purplish blocky shale" within Kayenta. Formation overall is the "silty facies" portion, gray and brownish, fine-grained sediments.',
#    'lng': -110.32,
#    'lt1': '"shale"',
#    'lt2': 'siltstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'UCMP 37302 (holotype), nearly complete skeleton. UCMP 37303, partial skeleton; third skeleton eroded and not collected',
#    'oei': 'Sinemurian',
#    'oid': 'occ:150849',
#    'oli': 'Pliensbachian',
#    'prc': '__',
#    'rid': 'ref:13844',
#    'rnk': 3,
#    'scm': 'bed is 120 (or 126) feet above base of Kayenta Formation.',
#    'sfm': 'Kayenta',
#    'sgr': 'Glen Canyon',
#    'smb': 'Silty Facies',
#    'ssc': 'bed',
#    'stp': 'Arizona',
#    'tdf': 'recombined as',
#    'tid': 'txn:55479',
#    'tna': 'Dilophosaurus wetherilli'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:13410',
#    'cny': 'Coconino',
#    'cxi': 43,
#    'dcr': '2002-03-19 13:13:26',
#    'dmd': '2005-07-01 14:47:01',
#    'eag': 199.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ff1': 'Y',
#    'ggc': '0.25 miles S of UCMP V4214. 20 miles N of Cameron, AZ in the Navajo Indian Reservation. Coordinates from UCMP website.',
#    'gsc': 'small collection',
#    'idn': 'Megalosaurus wetherilli',
#    'iid': 'var:55479',
#    'la1': 'blue',
#    'la2': 'brown,gray',
#    'lag': 182.7,
#    'lat': 36.099998,
#    'ldc': '"purplish blocky shale" within Kayenta. Formation overall is the "silty facies" portion, gray and brownish, fine-grained sediments.',
#    'lng': -110.300003,
#    'lt1': '"shale"',
#    'lt2': 'siltstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Sinemurian',
#    'oid': 'occ:150850',
#    'oli': 'Pliensbachian',
#    'prc': '__',
#    'rid': 'ref:13844',
#    'rnk': 3,
#    'scm': 'bed is 120 feet above base of Kayenta Formation.',
#    'sfm': 'Kayenta',
#    'sgr': 'Glen Canyon',
#    'smb': 'Silty Facies',
#    'ssc': 'bed',
#    'stp': 'Arizona',
#    'tdf': 'recombined as',
#    'tid': 'txn:55479',
#    'tna': 'Dilophosaurus wetherilli'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22648',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2017-10-12 14:45:47',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'coarse channel fill',
#    'ff1': 'Y',
#    'gcm': 'ETE sed env 1: fluvial, ETE sed env 2: channel ETE event: ., ETE env comment: 0; channel in moderately drained floodplain',
#    'ggc': 'coordinates from K. Carpenter (pers. comm. to M. Carrano). at the head of a draw, near the Medicine Bow River in S-central Wyoming',
#    'gsc': 'outcrop',
#    'la1': 'lenticular,coarse,intraclastic,brown,gray,white',
#    'lag': 145,
#    'lat': 42.017776,
#    'ldc': 'ETE rock type adj: "whte,brn,gray", ETE lithology comments: "crse,clastic+snd lens"',
#    'lng': -106.048615,
#    'lt1': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'AMNH 493, 516, 608, 655',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:219971',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:13100',
#    'rnk': 3,
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:52920',
#    'tna': 'Diplodocus longus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22648',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2005-04-06 14:02:26',
#    'dmd': '2005-04-06 16:02:56',
#    'eag': 157.3,
#    'eid': 'rei:12456',
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'coarse channel fill',
#    'ff1': 'Y',
#    'gcm': 'ETE sed env 1: fluvial, ETE sed env 2: channel ETE event: ., ETE env comment: 0; channel in moderately drained floodplain',
#    'ggc': 'coordinates from K. Carpenter (pers. comm. to M. Carrano). at the head of a draw, near the Medicine Bow River in S-central Wyoming',
#    'gsc': 'outcrop',
#    'idn': 'Morosaurus sp.',
#    'iid': 'txn:52968',
#    'la1': 'lenticular,coarse,intraclastic,brown,gray,white',
#    'lag': 145,
#    'lat': 42.017776,
#    'ldc': 'ETE rock type adj: "whte,brn,gray", ETE lithology comments: "crse,clastic+snd lens"',
#    'lng': -106.048615,
#    'lt1': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'AMNH 690, 823',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:219972',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:13100',
#    'rnk': 5,
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tdf': 'subjective synonym of',
#    'tid': 'txn:38697',
#    'tna': 'Camarasaurus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:22648',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2005-04-20 08:28:41',
#    'dmd': '2016-04-08 16:17:48',
#    'eag': 157.3,
#    'eid': 'rei:12664',
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'coarse channel fill',
#    'ff1': 'Y',
#    'gcm': 'ETE sed env 1: fluvial, ETE sed env 2: channel ETE event: ., ETE env comment: 0; channel in moderately drained floodplain',
#    'ggc': 'coordinates from K. Carpenter (pers. comm. to M. Carrano). at the head of a draw, near the Medicine Bow River in S-central Wyoming',
#    'gsc': 'outcrop',
#    'la1': 'lenticular,coarse,intraclastic,brown,gray,white',
#    'lag': 145,
#    'lat': 42.017776,
#    'ldc': 'ETE rock type adj: "whte,brn,gray", ETE lithology comments: "crse,clastic+snd lens"',
#    'lng': -106.048615,
#    'lt1': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:219973',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:58803',
#    'rnk': 3,
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:56491',
#    'tna': 'Stegosaurus stenops'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:22648',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2005-04-20 08:28:41',
#    'dmd': '2005-04-20 10:28:41',
#    'eag': 157.3,
#    'eid': 'rei:12665',
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'coarse channel fill',
#    'ff1': 'Y',
#    'gcm': 'ETE sed env 1: fluvial, ETE sed env 2: channel ETE event: ., ETE env comment: 0; channel in moderately drained floodplain',
#    'ggc': 'coordinates from K. Carpenter (pers. comm. to M. Carrano). at the head of a draw, near the Medicine Bow River in S-central Wyoming',
#    'gsc': 'outcrop',
#    'idn': 'Apatosaurus excelsus',
#    'iid': 'var:56547',
#    'la1': 'lenticular,coarse,intraclastic,brown,gray,white',
#    'lag': 145,
#    'lat': 42.017776,
#    'ldc': 'ETE rock type adj: "whte,brn,gray", ETE lithology comments: "crse,clastic+snd lens"',
#    'lng': -106.048615,
#    'lt1': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:219974',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:13281',
#    'rnk': 3,
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tdf': 'recombined as',
#    'tid': 'txn:52982',
#    'tna': 'Brontosaurus excelsus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22648',
#    'cny': 'Albany',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2012-01-23 16:13:58',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'coarse channel fill',
#    'ff1': 'Y',
#    'gcm': 'ETE sed env 1: fluvial, ETE sed env 2: channel ETE event: ., ETE env comment: 0; channel in moderately drained floodplain',
#    'ggc': 'coordinates from K. Carpenter (pers. comm. to M. Carrano). at the head of a draw, near the Medicine Bow River in S-central Wyoming',
#    'gsc': 'outcrop',
#    'idn': 'Creosaurus atrox',
#    'iid': 'txn:52970',
#    'la1': 'lenticular,coarse,intraclastic,brown,gray,white',
#    'lag': 145,
#    'lat': 42.017776,
#    'ldc': 'ETE rock type adj: "whte,brn,gray", ETE lithology comments: "crse,clastic+snd lens"',
#    'lng': -106.048615,
#    'lt1': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'AMNH FR 290, 324',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:219975',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:13098',
#    'rnk': 3,
#    'sfm': 'Morrison',
#    'smb': 'Lake Como',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tdf': 'subjective synonym of',
#    'tid': 'txn:52962',
#    'tna': 'Allosaurus fragilis'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:22650',
#    'cny': 'Hot Springs',
#    'cxi': 41,
#    'dcr': '2005-12-29 14:23:37',
#    'dmd': '2005-12-29 16:23:37',
#    'eag': 155.7,
#    'eid': 'rei:15652',
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'wet floodplain',
#    'ff1': 'Y',
#    'gcm': 'poorly drained floodplain',
#    'ggc': 'both Sauropod (S) and Beside Sauropods (BS) quarries are directly adjacent and in the same layer, so are here combined as one collection. Bones from different individuals are mixed throughout.',
#    'gsc': 'outcrop',
#    'idn': 'Diplodocidae indet.',
#    'la1': 'nodular,gray,green',
#    'lag': 150.8,
#    'lat': 43.380001,
#    'ldc': '"dark green or gray mudstone, containing abundant illite...Very hard silty carbonate nodules are fairly common in the upper half of the bone layer...In the lower layer of the bone bed abundant lignite fragments are present."',
#    'lm1': 'calcareous',
#    'lng': -108.120003,
#    'lt1': 'mudstone',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:219978',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:15179',
#    'rnk': 9,
#    'scm': 'originally entered as Cloverly (Aptian-Albian) but later abstract says Morrison; quarry has been placed just below the Kimm-Tith boundary',
#    'sfm': 'Morrison',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:38664',
#    'tna': 'Diplodocidae'},
#   {'ath': 'P. Mannion',
#    'ati': 'prs:435',
#    'cc2': 'US',
#    'cid': 'col:22650',
#    'cny': 'Hot Springs',
#    'cxi': 41,
#    'dcr': '2015-04-14 05:58:48',
#    'dmd': '2018-04-04 17:12:33',
#    'eag': 155.7,
#    'eid': 'rei:31060',
#    'eni': 'prs:435',
#    'ent': 'P. Mannion',
#    'env': 'wet floodplain',
#    'ff1': 'Y',
#    'gcm': 'poorly drained floodplain',
#    'ggc': 'both Sauropod (S) and Beside Sauropods (BS) quarries are directly adjacent and in the same layer, so are here combined as one collection. Bones from different individuals are mixed throughout.',
#    'gsc': 'outcrop',
#    'idn': 'Apatosaurinae indet. informal',
#    'la1': 'nodular,gray,green',
#    'lag': 150.8,
#    'lat': 43.380001,
#    'ldc': '"dark green or gray mudstone, containing abundant illite...Very hard silty carbonate nodules are fairly common in the upper half of the bone layer...In the lower layer of the bone bed abundant lignite fragments are present."',
#    'lm1': 'calcareous',
#    'lng': -108.120003,
#    'lt1': 'mudstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'NSMT-PV 20375',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:219979',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:55026',
#    'rnk': 25,
#    'scm': 'originally entered as Cloverly (Aptian-Albian) but later abstract says Morrison; quarry has been placed just below the Kimm-Tith boundary',
#    'sfm': 'Morrison',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:66543',
#    'tna': 'Apatosaurinae'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:22650',
#    'cny': 'Hot Springs',
#    'cxi': 41,
#    'dcr': '2007-01-03 08:04:27',
#    'dmd': '2007-01-03 10:04:27',
#    'eag': 155.7,
#    'eid': 'rei:18816',
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'wet floodplain',
#    'ff1': 'Y',
#    'gcm': 'poorly drained floodplain',
#    'ggc': 'both Sauropod (S) and Beside Sauropods (BS) quarries are directly adjacent and in the same layer, so are here combined as one collection. Bones from different individuals are mixed throughout.',
#    'gsc': 'outcrop',
#    'la1': 'nodular,gray,green',
#    'lag': 150.8,
#    'lat': 43.380001,
#    'ldc': '"dark green or gray mudstone, containing abundant illite...Very hard silty carbonate nodules are fairly common in the upper half of the bone layer...In the lower layer of the bone bed abundant lignite fragments are present."',
#    'lm1': 'calcareous',
#    'lng': -108.120003,
#    'lt1': 'mudstone',
#    'ocm': 'WDC B',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:219980',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:19566',
#    'rnk': 3,
#    'scm': 'originally entered as Cloverly (Aptian-Albian) but later abstract says Morrison; quarry has been placed just below the Kimm-Tith boundary',
#    'sfm': 'Morrison',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:63764',
#    'tna': 'Camarasaurus lentus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22678',
#    'cny': 'Hot Spings',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2014-02-24 13:38:27',
#    'eag': 155.7,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'crevasse splay',
#    'ff1': 'Y',
#    'ggc': 'name originally given as "RB" but should be "BB"',
#    'gsc': 'outcrop',
#    'idn': 'Diplodocus sp.',
#    'lag': 145,
#    'lat': 43.630001,
#    'lng': -108.199997,
#    'lt1': '"siliciclastic"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:220055',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:5760',
#    'rnk': 5,
#    'scm': 'seven fossiliferous layers',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:38669',
#    'tna': 'Diplodocus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:22678',
#    'cny': 'Hot Spings',
#    'cxi': 41,
#    'dcr': '2014-02-24 13:38:15',
#    'dmd': '2014-02-24 13:38:27',
#    'eag': 155.7,
#    'eid': 'rei:29729',
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'crevasse splay',
#    'ff1': 'Y',
#    'ggc': 'name originally given as "RB" but should be "BB"',
#    'gsc': 'outcrop',
#    'idn': 'Camarasaurus sp.',
#    'lag': 145,
#    'lat': 43.630001,
#    'lng': -108.199997,
#    'lt1': '"siliciclastic"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:220056',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:5760',
#    'rnk': 5,
#    'scm': 'seven fossiliferous layers',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:38697',
#    'tna': 'Camarasaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22678',
#    'cny': 'Hot Spings',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2014-02-24 13:38:27',
#    'eag': 155.7,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'crevasse splay',
#    'ff1': 'Y',
#    'ggc': 'name originally given as "RB" but should be "BB"',
#    'gsc': 'outcrop',
#    'idn': 'Stegosaurus sp.',
#    'lag': 145,
#    'lat': 43.630001,
#    'lng': -108.199997,
#    'lt1': '"siliciclastic"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:220057',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:5760',
#    'rnk': 5,
#    'scm': 'seven fossiliferous layers',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:38814',
#    'tna': 'Stegosaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22678',
#    'cny': 'Hot Spings',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2014-02-24 13:38:27',
#    'eag': 155.7,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'crevasse splay',
#    'ff1': 'Y',
#    'ggc': 'name originally given as "RB" but should be "BB"',
#    'gsc': 'outcrop',
#    'idn': 'Allosaurus sp.',
#    'lag': 145,
#    'lat': 43.630001,
#    'lng': -108.199997,
#    'lt1': '"siliciclastic"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:220058',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:5760',
#    'rnk': 5,
#    'scm': 'seven fossiliferous layers',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:38590',
#    'tna': 'Allosaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22678',
#    'cny': 'Hot Spings',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2014-02-24 13:38:27',
#    'eag': 155.7,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'crevasse splay',
#    'ff1': 'Y',
#    'ggc': 'name originally given as "RB" but should be "BB"',
#    'gsc': 'outcrop',
#    'idn': 'Camptosaurus sp.',
#    'lag': 145,
#    'lat': 43.630001,
#    'lng': -108.199997,
#    'lt1': '"siliciclastic"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:220059',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:5760',
#    'rnk': 5,
#    'scm': 'seven fossiliferous layers',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:38748',
#    'tna': 'Camptosaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22678',
#    'cny': 'Hot Spings',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2014-02-24 13:38:27',
#    'eag': 155.7,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'crevasse splay',
#    'ff1': 'Y',
#    'ggc': 'name originally given as "RB" but should be "BB"',
#    'gsc': 'outcrop',
#    'idn': 'Barosaurus sp.',
#    'lag': 145,
#    'lat': 43.630001,
#    'lng': -108.199997,
#    'lt1': '"siliciclastic"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:220060',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:5760',
#    'rnk': 5,
#    'scm': 'seven fossiliferous layers',
#    'sfm': 'Morrison',
#    'ssc': 'group of beds',
#    'stp': 'Wyoming',
#    'tid': 'txn:38666',
#    'tna': 'Barosaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22711',
#    'cny': 'Uintah',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2011-11-10 13:30:29',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'wet floodplain',
#    'gcm': '"poorly drained floodplain"',
#    'ggc': 'northern part of Dinosaur National Monument',
#    'gsc': 'small collection',
#    'idn': 'Allosaurus sp.',
#    'lag': 145,
#    'lat': 40.423611,
#    'lng': -109.205833,
#    'lt1': 'not reported',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:220162',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:15179',
#    'rnk': 5,
#    'scm': 'upper part of member, "zone 6"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:38590',
#    'tna': 'Allosaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22711',
#    'cny': 'Uintah',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2011-11-10 13:30:29',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'wet floodplain',
#    'gcm': '"poorly drained floodplain"',
#    'ggc': 'northern part of Dinosaur National Monument',
#    'gsc': 'small collection',
#    'idn': 'Diplodocus sp.',
#    'lag': 145,
#    'lat': 40.423611,
#    'lng': -109.205833,
#    'lt1': 'not reported',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:220163',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:15179',
#    'rnk': 5,
#    'scm': 'upper part of member, "zone 6"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:38669',
#    'tna': 'Diplodocus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22711',
#    'cny': 'Uintah',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2011-11-10 13:30:29',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'wet floodplain',
#    'gcm': '"poorly drained floodplain"',
#    'ggc': 'northern part of Dinosaur National Monument',
#    'gsc': 'small collection',
#    'idn': 'Stegosaurus sp.',
#    'lag': 145,
#    'lat': 40.423611,
#    'lng': -109.205833,
#    'lt1': 'not reported',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:220164',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:15179',
#    'rnk': 5,
#    'scm': 'upper part of member, "zone 6"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:38814',
#    'tna': 'Stegosaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22711',
#    'cny': 'Uintah',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2011-11-10 13:30:29',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'wet floodplain',
#    'gcm': '"poorly drained floodplain"',
#    'ggc': 'northern part of Dinosaur National Monument',
#    'gsc': 'small collection',
#    'idn': 'Dryosaurus sp.',
#    'lag': 145,
#    'lat': 40.423611,
#    'lng': -109.205833,
#    'lt1': 'not reported',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:220165',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:15179',
#    'rnk': 5,
#    'scm': 'upper part of member, "zone 6"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:38731',
#    'tna': 'Dryosaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22711',
#    'cny': 'Uintah',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2011-11-10 13:30:29',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'wet floodplain',
#    'gcm': '"poorly drained floodplain"',
#    'ggc': 'northern part of Dinosaur National Monument',
#    'gsc': 'small collection',
#    'idn': 'Camptosaurus sp.',
#    'lag': 145,
#    'lat': 40.423611,
#    'lng': -109.205833,
#    'lt1': 'not reported',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:220166',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:15179',
#    'rnk': 5,
#    'scm': 'upper part of member, "zone 6"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:38748',
#    'tna': 'Camptosaurus'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22717',
#    'cny': 'Bernalillo',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2008-10-07 09:38:32',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'coarse channel fill',
#    'ff1': 'Y',
#    'gcm': 'ETE sed env 1: fluvial, ETE sed env 2: floodplain ETE event: ., ETE env comment: 0; "the mixed fill of an abandoned channel"',
#    'ggc': 'UTM zone 13, 3897311 N, 0305883 E; near Laguna, drainage channel in narrow arroyo on E flank, Mesa Gigante, W-central NM',
#    'gsc': 'outcrop',
#    'idn': 'Saurischia indet.',
#    'la1': 'lenticular,current ripples,fine,coarse,intraclastic,gray',
#    'la2': 'lenticular',
#    'lag': 145,
#    'lat': 35.197208,
#    'ldc': '"a 1.1-m-thick sandstone lens that overlies and fills scours in less-well indurated, underlying sandstone. The bone-bearing sandstone is a well indurated, yellowish-gray, fine- to coarse-grained, subangular, poorly sorted subarkose. This unit is trough-bedded with some clay-pebble conglomerate clasts at the base of trough sets. Some thin (< 5 cm thick), discontinuous, sub-meter-scale mudstone lenses are also present."',
#    'lf1': 'lithified',
#    'lm1': 'conglomeratic',
#    'lng': -107.13279,
#    'lt1': 'sandstone',
#    'lt2': 'mudstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:220199',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:9727',
#    'rnk': 25,
#    'scm': 'ETE dating method: time_unit, ETE age comment: . radiometric intage_max, radiometric intage_min; upper middle part of formation; upper part of member, 26 m below upper contact with Jackpile Mb',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'New Mexico',
#    'tid': 'txn:38505',
#    'tna': 'Saurischia'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22717',
#    'cny': 'Bernalillo',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2008-10-07 09:38:32',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'coarse channel fill',
#    'ff1': 'Y',
#    'gcm': 'ETE sed env 1: fluvial, ETE sed env 2: floodplain ETE event: ., ETE env comment: 0; "the mixed fill of an abandoned channel"',
#    'ggc': 'UTM zone 13, 3897311 N, 0305883 E; near Laguna, drainage channel in narrow arroyo on E flank, Mesa Gigante, W-central NM',
#    'gsc': 'outcrop',
#    'idn': 'Allosauridae indet.',
#    'la1': 'lenticular,current ripples,fine,coarse,intraclastic,gray',
#    'la2': 'lenticular',
#    'lag': 145,
#    'lat': 35.197208,
#    'ldc': '"a 1.1-m-thick sandstone lens that overlies and fills scours in less-well indurated, underlying sandstone. The bone-bearing sandstone is a well indurated, yellowish-gray, fine- to coarse-grained, subangular, poorly sorted subarkose. This unit is trough-bedded with some clay-pebble conglomerate clasts at the base of trough sets. Some thin (< 5 cm thick), discontinuous, sub-meter-scale mudstone lenses are also present."',
#    'lf1': 'lithified',
#    'lm1': 'conglomeratic',
#    'lng': -107.13279,
#    'lt1': 'sandstone',
#    'lt2': 'mudstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'Saurophaganax-like',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:220200',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'rid': 'ref:9727',
#    'rnk': 9,
#    'scm': 'ETE dating method: time_unit, ETE age comment: . radiometric intage_max, radiometric intage_min; upper middle part of formation; upper part of member, 26 m below upper contact with Jackpile Mb',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'New Mexico',
#    'tid': 'txn:38589',
#    'tna': 'Allosauridae'},
#   {'ath': 'A. Behrensmeyer',
#    'ati': 'prs:24',
#    'cc2': 'US',
#    'cid': 'col:22717',
#    'cny': 'Bernalillo',
#    'cxi': 41,
#    'dcr': '2002-07-10 20:49:32',
#    'dmd': '2008-10-07 09:38:32',
#    'eag': 157.3,
#    'eni': 'prs:24',
#    'ent': 'A. Behrensmeyer',
#    'env': 'coarse channel fill',
#    'ff1': 'Y',
#    'gcm': 'ETE sed env 1: fluvial, ETE sed env 2: floodplain ETE event: ., ETE env comment: 0; "the mixed fill of an abandoned channel"',
#    'ggc': 'UTM zone 13, 3897311 N, 0305883 E; near Laguna, drainage channel in narrow arroyo on E flank, Mesa Gigante, W-central NM',
#    'gsc': 'outcrop',
#    'idn': 'Diplodocidae indet.',
#    'la1': 'lenticular,current ripples,fine,coarse,intraclastic,gray',
#    'la2': 'lenticular',
#    'lag': 145,
#    'lat': 35.197208,
# ...
#    'ggc': 'Site is northwest of Delta, and 22 mi. SE of Grand Junction, in Wells Gulch, SW 1/4, sec 26, T14S, R98W, 6th P.M.',
#    'gsc': 'small collection',
#    'idn': 'cf. Echinodon sp.',
#    'la1': 'brown,red',
#    'la2': 'gray',
#    'lag': 152.1,
#    'lat': 38.806,
#    'lng': -108.322304,
#    'lt1': 'mudstone',
#    'lt2': 'sandstone',
#    'ocm': 'tooth fragment',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:1383400',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:63745',
#    'rnk': 5,
#    'scm': 'Approx. 38 m below the top of the Salt Wash Member',
#    'sfm': 'Morrison',
#    'slb': 260,
#    'slo': 'bottom to top',
#    'sls': 'N-Thoroughfare',
#    'smb': 'Salt Wash',
#    'ssc': 'bed',
#    'stp': 'Colorado',
#    'tid': 'txn:38717',
#    'tna': 'Echinodon'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:53021',
#    'cny': 'Delta',
#    'cxi': 125,
#    'dcr': '2017-11-02 14:51:30',
#    'dmd': '2017-11-02 14:51:44',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'dry floodplain',
#    'ff1': 'Y',
#    'gcm': '"deposited near the distal margin of a riverine fan-like channel system", in a well-drained floodplain',
#    'ggc': 'Site is northwest of Delta, and 22 mi. SE of Grand Junction, in Wells Gulch, SW 1/4, sec 26, T14S, R98W, 6th P.M.',
#    'gsc': 'small collection',
#    'idn': 'Coelurosauria ? indet.',
#    'la1': 'brown,red',
#    'la2': 'gray',
#    'lag': 152.1,
#    'lat': 38.806,
#    'lng': -108.322304,
#    'lt1': 'mudstone',
#    'lt2': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'tooth fragments',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:1383401',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:63745',
#    'rnk': 12,
#    'scm': 'Approx. 38 m below the top of the Salt Wash Member',
#    'sfm': 'Morrison',
#    'slb': 260,
#    'slo': 'bottom to top',
#    'sls': 'N-Thoroughfare',
#    'smb': 'Salt Wash',
#    'ssc': 'bed',
#    'stp': 'Colorado',
#    'tid': 'txn:53940',
#    'tna': 'Coelurosauria'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:190894',
#    'cny': 'Big Horn',
#    'cxi': 41,
#    'dcr': '2017-12-20 15:07:12',
#    'dmd': '2017-12-20 15:07:12',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'a few hundred meters N of where Bighorn River dissects the Sheep Mtn. anticline',
#    'gsc': 'small collection',
#    'idn': 'Diplodocus ? sp.',
#    'lag': 145,
#    'lat': 44.637482,
#    'lng': -108.124908,
#    'lt1': 'not reported',
#    'ocm': 'femora, ribs, vertebrae',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:1388595',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:64180',
#    'rnk': 5,
#    'sfm': 'Morrison',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:38669',
#    'tna': 'Diplodocus'},
#   {'ath': 'P. Holroyd',
#    'ati': 'prs:257',
#    'cc2': 'US',
#    'cid': 'col:191718',
#    'cny': 'Grand',
#    'cxi': 41,
#    'dcr': '2018-02-10 00:08:30',
#    'dmd': '2018-02-10 00:08:30',
#    'eag': 163.5,
#    'eni': 'prs:257',
#    'ent': 'P. Holroyd',
#    'env': 'terrestrial indet.',
#    'gsc': 'small collection',
#    'idn': 'Fruitadens ? sp.',
#    'lag': 145,
#    'lat': 38.992222,
#    'ldc': '"The locality is at the top of a rounded, pale-gray knob ... The  hill  preserves  an  irregular  sequence  of  mudstone  and  thinner  sandstone  beds,  mostly  of  uniform  pale  color. The sandstone beds are more resistant to weath-ering  and  appear  rounded  in  profile  when  exposed.  ...the beds seem to lack sedimentary structures and are strongly indurated. The mudstone  beds  are  smectitic  and  calcareous,  contain-ing a substantial proportion of fine- to very fine grained sand. Small flecks of biotite are present, and barite nod-ules  are  common  with  some  as  large  as  10  cm.  Bone  has been found at low density throughout much of the worked section, and does not appear to be concentrated at a particular horizon or horizons."',
#    'lng': -109.269165,
#    'lt1': 'mudstone',
#    'lt2': 'sandstone',
#    'oei': 'Late Jurassic',
#    'oid': 'occ:1392259',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:64661',
#    'rnk': 5,
#    'scm': '"coarse stratigraphic placement of the CMQ is likely low in the Brushy Basin Member"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:157200',
#    'tna': 'Fruitadens'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:189379',
#    'cny': 'Emery',
#    'cxi': 132,
#    'dcr': '2018-02-12 10:10:15',
#    'dmd': '2018-02-12 10:10:19',
#    'eag': 190.8,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'fluvial indet.',
#    'ff1': 'Y',
#    'ggc': '"The tracks and invertebrate fossils were found 2.8 miles nearly due west of Lost Spring at the top of the cliff on the north side of the main fork of Iron Wash where it passes through the Reef."',
#    'gsc': 'small collection',
#    'idn': 'Dinosauria indet.',
#    'lag': 182.7,
#    'lat': 38.75351,
#    'lng': -110.514175,
#    'lt1': '"siliciclastic"',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Pliensbachian',
#    'oid': 'occ:1392443',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:63595',
#    'rnk': 25,
#    'scm': '"Although these beds are arbitrarily included in the Navajo, they might equally well be included in the Kayenta."',
#    'sfm': 'Kayenta/Navajo Sandstone',
#    'sgr': 'Glen Canyon',
#    'stp': 'Utah',
#    'tid': 'txn:52775',
#    'tna': 'Dinosauria'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:191750',
#    'cny': 'Coconino',
#    'cxi': 134,
#    'dcr': '2018-02-12 10:55:21',
#    'dmd': '2018-02-12 10:55:24',
#    'eag': 201.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ff1': 'Y',
#    'ggc': 'ca. 12 mi. SE of Cameron',
#    'gsc': 'outcrop',
#    'idn': 'Dinosauria indet.',
#    'lag': 199.3,
#    'lat': 35.780045,
#    'ldc': '"shaley sandstone"',
#    'lm1': 'argillaceous',
#    'lng': -111.238853,
#    'lt1': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Hettangian',
#    'oid': 'occ:1392445',
#    'prc': '__',
#    'rid': 'ref:64683',
#    'rnk': 25,
#    'scm': 'orig. assigned to Upper Triassic, but upper Wingate now considered Lower Jurassic. Just below contact w/overlying Moenave Fm.',
#    'sfm': 'Wingate Sandstone',
#    'sgr': 'Glen Canyon',
#    'smb': 'Lukachukai',
#    'ssc': 'bed',
#    'stp': 'Arizona',
#    'tid': 'txn:52775',
#    'tna': 'Dinosauria'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:191751',
#    'cny': 'Coconino',
#    'cxi': 132,
#    'dcr': '2018-02-12 11:01:57',
#    'dmd': '2018-02-12 11:01:57',
#    'eag': 190.8,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'dune',
#    'ff1': 'Y',
#    'ggc': '0.5 mi. N of Coppermine (Copper Mine) Trading Post, on the Kaibeto Plateau',
#    'gsc': 'small collection',
#    'idn': 'Segisaurus ? sp.',
#    'lag': 182.7,
#    'lat': 36.636986,
#    'lng': -111.450195,
#    'lt1': 'sandstone',
#    'oei': 'Pliensbachian',
#    'oid': 'occ:1392446',
#    'prc': '__',
#    'rid': 'ref:64683',
#    'rnk': 5,
#    'sfm': 'Navajo Sandstone',
#    'sgr': 'Glen Canyon',
#    'ssc': 'bed',
#    'stp': 'Arizona',
#    'tid': 'txn:38524',
#    'tna': 'Segisaurus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:192426',
#    'cny': 'Washington',
#    'cxi': 43,
#    'dcr': '2018-04-03 14:45:57',
#    'dmd': '2018-04-03 14:46:01',
#    'eag': 199.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ff1': 'Y',
#    'ggc': 'between the West Temple and the mouth of the Parunuweap, Zion NP',
#    'gsc': 'outcrop',
#    'idn': 'Dinosauria indet.',
#    'la1': 'desiccation cracks,hematitic,red',
#    'lag': 182.7,
#    'lat': 37.204269,
#    'ldc': '"Sandstone, red, in beds 6 inches to 3 feet thick: that overlap irregularly within short distances; a series of lenses that vary much in composition and texture, but rock of different coarseness roughly segregated as in stream beds; upper 10 ± feet more evenly bedded; includes two layers of gray limestone conglomerate each about 1 foot thick; many foliation surfaces sun-baked and cracked; a few. dinosaur tracks and fragmentary shells (unios?) ; microscopic examination by C. S. Ross of a representative sample of the red rock shows "fine-grained argillaceous sandstone; grains partly angular and variable in size; many grains bits of fine quartzite; groundmass clay and dolomite (?) grains coated with hematite; reduced in places to form white spots"."',
#    'lm1': 'argillaceous',
#    'lng': -113.001343,
#    'lt1': 'sandstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'footprints',
#    'oei': 'Sinemurian',
#    'oid': 'occ:1396818',
#    'oli': 'Pliensbachian',
#    'prc': '__',
#    'ptd': 'NPS',
#    'rid': 'ref:65129',
#    'rnk': 25,
#    'sfm': 'Kayenta',
#    'sgr': 'Glen Canyon',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:52775',
#    'tna': 'Dinosauria'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:192428',
#    'cny': 'San Juan',
#    'cxi': 41,
#    'dcr': '2018-04-03 16:49:14',
#    'dmd': '2018-04-03 16:49:17',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'from talus in Montezuma Canyon',
#    'gsc': 'small collection',
#    'idn': 'Diplodocidae indet.',
#    'lag': 145,
#    'lat': 37.559715,
#    'lng': -109.197891,
#    'lt1': 'not reported',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': '"sauropod dinosaur of the Brontosaurus-Apatosaurus group"',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:1396839',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:65131',
#    'rnk': 9,
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:38664',
#    'tna': 'Diplodocidae'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:192428',
#    'cny': 'San Juan',
#    'cxi': 41,
#    'dcr': '2018-04-03 16:49:14',
#    'dmd': '2018-04-03 16:49:14',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'from talus in Montezuma Canyon',
#    'gsc': 'small collection',
#    'idn': 'Antrodemus ? sp.',
#    'iid': 'txn:52904',
#    'lag': 145,
#    'lat': 37.559715,
#    'lng': -109.197891,
#    'lt1': 'not reported',
#    'ocm': 'proximal tibia',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:1396840',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:65131',
#    'rnk': 5,
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tdf': 'subjective synonym of',
#    'tid': 'txn:38590',
#    'tna': 'Allosaurus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:192432',
#    'cny': 'San Juan',
#    'cxi': 41,
#    'dcr': '2018-04-04 14:12:52',
#    'dmd': '2018-04-04 14:12:52',
#    'eag': 155.7,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'terrestrial indet.',
#    'ggc': 'near White Mesa',
#    'gsc': 'small collection',
#    'idn': 'Camarasaurus ? sp.',
#    'lag': 145,
#    'lat': 37.465836,
#    'lng': -109.467621,
#    'lt1': 'not reported',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:1396868',
#    'oli': 'Early Tithonian',
#    'prc': '__',
#    'rid': 'ref:65141',
#    'rnk': 5,
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Utah',
#    'tid': 'txn:38697',
#    'tna': 'Camarasaurus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:22650',
#    'cny': 'Hot Springs',
#    'cxi': 41,
#    'dcr': '2018-04-04 17:11:54',
#    'dmd': '2018-04-04 17:15:46',
#    'eag': 155.7,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'wet floodplain',
#    'ff1': 'Y',
#    'gcm': 'poorly drained floodplain',
#    'ggc': 'both Sauropod (S) and Beside Sauropods (BS) quarries are directly adjacent and in the same layer, so are here combined as one collection. Bones from different individuals are mixed throughout.',
#    'gsc': 'outcrop',
#    'idn': 'Deinonychosauria ? indet.',
#    'la1': 'nodular,gray,green',
#    'lag': 150.8,
#    'lat': 43.380001,
#    'ldc': '"dark green or gray mudstone, containing abundant illite...Very hard silty carbonate nodules are fairly common in the upper half of the bone layer...In the lower layer of the bone bed abundant lignite fragments are present."',
#    'lm1': 'calcareous',
#    'lng': -108.120003,
#    'lt1': 'mudstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'small teeth; WC BS-641, 885, 889',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:1396902',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:65148',
#    'rnk': 11,
#    'scm': 'originally entered as Cloverly (Aptian-Albian) but later abstract says Morrison; quarry has been placed just below the Kimm-Tith boundary',
#    'sfm': 'Morrison',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:57260',
#    'tna': 'Deinonychosauria'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:22650',
#    'cny': 'Hot Springs',
#    'cxi': 41,
#    'dcr': '2018-04-04 17:11:54',
#    'dmd': '2018-04-04 17:15:46',
#    'eag': 155.7,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'wet floodplain',
#    'ff1': 'Y',
#    'gcm': 'poorly drained floodplain',
#    'ggc': 'both Sauropod (S) and Beside Sauropods (BS) quarries are directly adjacent and in the same layer, so are here combined as one collection. Bones from different individuals are mixed throughout.',
#    'gsc': 'outcrop',
#    'idn': 'Allosaurus sp.',
#    'la1': 'nodular,gray,green',
#    'lag': 150.8,
#    'lat': 43.380001,
#    'ldc': '"dark green or gray mudstone, containing abundant illite...Very hard silty carbonate nodules are fairly common in the upper half of the bone layer...In the lower layer of the bone bed abundant lignite fragments are present."',
#    'lm1': 'calcareous',
#    'lng': -108.120003,
#    'lt1': 'mudstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'ocm': 'large teeth; WDC BS-618, 621, 643, 691, 700, 715, 716, 725, 749, 798, 820, 835–837, 846, 915',
#    'oei': 'Late Kimmeridgian',
#    'oid': 'occ:1396903',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:65148',
#    'rnk': 5,
#    'scm': 'originally entered as Cloverly (Aptian-Albian) but later abstract says Morrison; quarry has been placed just below the Kimm-Tith boundary',
#    'sfm': 'Morrison',
#    'ssc': 'bed',
#    'stp': 'Wyoming',
#    'tid': 'txn:38590',
#    'tna': 'Allosaurus'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:192447',
#    'cny': 'Mesa',
#    'cxi': 41,
#    'dcr': '2018-04-06 15:36:25',
#    'dmd': '2018-04-06 15:36:34',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'pond',
#    'ff1': 'Y',
#    'gcm': '"pond-marsh deposit"',
#    'ggc': 'near Fruita, CO',
#    'gsc': 'small collection',
#    'idn': 'Dinosauria indet.',
#    'lag': 145,
#    'lat': 39.150227,
#    'lng': -108.771576,
#    'lt1': 'mudstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:1397009',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:65150',
#    'rnk': 25,
#    'scm': 'above "channel 7"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Colorado',
#    'tid': 'txn:52775',
#    'tna': 'Dinosauria'},
#   {'ath': 'M. Carrano',
#    'ati': 'prs:14',
#    'cc2': 'US',
#    'cid': 'col:192448',
#    'cny': 'Mesa',
#    'cxi': 41,
#    'dcr': '2018-04-06 15:37:59',
#    'dmd': '2018-04-06 15:38:09',
#    'eag': 157.3,
#    'eni': 'prs:14',
#    'ent': 'M. Carrano',
#    'env': 'pond',
#    'ff1': 'Y',
#    'gcm': '"pond-marsh deposit"',
#    'ggc': 'near Fruita, CO',
#    'gsc': 'small collection',
#    'idn': 'Dinosauria indet.',
#    'la1': 'volcaniclastic',
#    'lag': 145,
#    'lat': 39.150227,
#    'lng': -108.771576,
#    'lt1': 'mudstone',
#    'mdf': 'M. Carrano',
#    'mdi': 'prs:14',
#    'oei': 'Kimmeridgian',
#    'oid': 'occ:1397013',
#    'oli': 'Tithonian',
#    'prc': '__',
#    'ptd': 'FED',
#    'rid': 'ref:65150',
#    'rnk': 25,
#    'scm': 'above "channel 1"',
#    'sfm': 'Morrison',
#    'smb': 'Brushy Basin',
#    'ssc': 'bed',
#    'stp': 'Colorado',
#    'tid': 'txn:52775',
#    'tna': 'Dinosauria'},
#   ...],
#  'title': 'PBDB Data Service'}

# %% [markdown]
# Your data has now been read and stored as a json file and awaits further exploration!
